# %%
#Dependencies
import os
import csv
import pandas as pd
import numpy as np

# %%
#read csv file in a dataframe

loaded_file= "googleplaystore.csv"
playstore_data = pd.read_csv(loaded_file)

playstore_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
playstore_data.sort_values([''])

# %%
#What can we do with this data....?

#Sort and see who has the most installs
##Get the app name from "App" and the most "Installs" into a df
#Paid apps vs Free apps- average reviews, number of installs- free=more is my hypothesis, 
#Which genre has the most downloads on average?
#Which genre has the best reviews on average?
#What other factors might skew the data? -installs, varies by device, .....
#Does the content rating affect number of downloads?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-72ce7ae109f9> in <module>
#       1 #Count by genre
#       2
# ----> 3 genre_breakdown = playstore_data.loc[['App','Rating', 'Reviews','Installs', 'Genre']]
#       4
#       5 genre_breakdown
#
# ~\anaconda\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
# ...
